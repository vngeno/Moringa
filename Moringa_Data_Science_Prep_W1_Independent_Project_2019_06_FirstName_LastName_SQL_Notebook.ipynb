# %% [markdown]
# <a href="https://colab.research.google.com/github/vngeno/Moringa/blob/main/Moringa_Data_Science_Prep_W1_Independent_Project_2019_06_FirstName_LastName_SQL_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#We will load the sql extension into our environment
#
# %load_ext sql
#Now connect to our in memory sqlite database
#
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
#we'll now import the python libraries that we'll need in the database
#
import csv
import pandas as pd

# %%
#Loading the table from csv file
#
with open('Karamoja.csv','r') as f:
  Karamoja = pd.read_csv(f, index_col=0, encoding='utf-8')
#%sql DROP TABLE if EXISTS Karamoja
# %sql PERSIST Karamoja;
# Out:
#  * sqlite://
# 'Persisted karamoja'

# %%
#Let's preview our table to understand it
# %sql SELECT * FROM Karamoja
# Out:
#  * sqlite://
# Done.
# [(263, 'KACHERI', 'KOTIDO', 17244, 1067176155, 'Y', 354.20741069999997, 1137.467019, 7023.533691, 6434.342449, 528.1242294, 2279091.779, 600723.8929),
#  (264, 'KOTIDO', 'KOTIDO', 52771, 597575188, 'Y', 367.89052319999996, 1162.9966869999998, 13587.990759999999, 12455.59264, 824.7670809, 4582294.492, 959201.3825),
#  (265, 'KOTIDO TOWN COUNCIL', 'KOTIDO', 27389, 23972401, 'Y', 369.3141771, 1167.005832, 1656.5318550000002, 1520.322052, 8.561643817, 561476.4874, 9991.488268000001),
#  (266, 'NAKAPERIMORU', 'KOTIDO', 38775, 419111591, 'Y', 283.3245689, 852.3665784, 7087.823334000001, 6761.488901000001, 45.72171184, 1915695.928, 38971.65908),
#  (267, 'PANYANGARA', 'KOTIDO', 65704, 880955930, 'Y', 373.8369255, 1283.859882, 10398.24939, 10111.198129999999, 172.6119139, 3779939.224, 221609.5114),
#  (268, 'RENGEN', 'KOTIDO', 41273, 652744859, 'Y', 271.18584310000006, 1047.180128, 13278.52043, 12964.49973, 171.5857036, 3515788.789, 179681.139),
# ...

# %%
#Display a list of Sub Counties and their population and areas.
# %%sql
SELECT SUBCOUNTY_NAME , POP, AREA FROM Karamoja
# Out:
#  * sqlite://
# Done.
# [('KACHERI', 17244, 1067176155),
#  ('KOTIDO', 52771, 597575188),
#  ('KOTIDO TOWN COUNCIL', 27389, 23972401),
#  ('NAKAPERIMORU', 38775, 419111591),
#  ('PANYANGARA', 65704, 880955930),
#  ('RENGEN', 41273, 652744859),
#  ('KAABONG  EAST', 42221, 60801942),
#  ('KAABONG TOWN COUNCIL', 38857, 13071455),
#  ('KAABONG WEST', 41454, 67612362),
#  ('KALAPATA', 99203, 223116860),
#  ('KAMION', 60070, 1199409465),
#  ('KAPEDO', 33951, 304557831),
#  ('KATHILE', 56870, 228457417),
#  ('KAWALAKOL', 37691, 1742041261),
#  ('LOBALANGIT', 22907, 302572789),
#  ('LODIKO', 31820, 397700845),
#  ('LOLELIA', 100919, 1069331387),
#  ('LOYORO', 16608, 1330019236),
#  ('NAPORE (KARENGA)', 20394, 309577387),
#  ('SIDOK', 24092, 125330583),
#  ('ABIM', 14377, 188613057),
#  ('ABIM TOWN COUNCIL', 11489, 115941152),
#  ('ALEREK', 12573, 1255760525),
#  ('LOTUKEI', 18641, 191684465),
#  ('MORULEM', 16834, 250364895),
#  ('KARITA', 45015, 658008801),
#  ('LOROO', 22541, 371970302),
# ...

# %%
#Sort the list of districts by total crop area (descending order).
# %%sql
SELECT DISTRICT_NAME FROM Karamoja
  ORDER BY Crop_Area_Ha DESC;
# Out:
#  * sqlite://
# Done.
# [('KOTIDO',),
#  ('KOTIDO',),
#  ('KOTIDO',),
#  ('KOTIDO',),
#  ('KOTIDO',),
#  ('KAABONG',),
#  ('NAPAK',),
#  ('NAKAPIRIPIRIT',),
#  ('NAKAPIRIPIRIT',),
#  ('NAPAK',),
#  ('NAKAPIRIPIRIT',),
#  ('KAABONG',),
#  ('NAKAPIRIPIRIT',),
#  ('NAKAPIRIPIRIT',),
#  ('NAPAK',),
#  ('NAPAK',),
#  ('KAABONG',),
#  ('KAABONG',),
#  ('AMUDAT',),
#  ('MOROTO',),
#  ('KAABONG',),
#  ('MOROTO',),
#  ('NAKAPIRIPIRIT',),
#  ('KAABONG',),
#  ('NAPAK',),
#  ('KOTIDO',),
#  ('AMUDAT',),
#  ('AMUDAT',),
#  ('KAABONG',),
#  ('KAABONG',),
#  ('ABIM',),
#  ('NAPAK',),
#  ('NAKAPIRIPIRIT',),
#  ('MOROTO',),
#  ('NAPAK',),
#  ('KAABONG',),
#  ('ABIM',),
#  ('KAABONG',),
#  ('KAABONG',),
#  ('KAABONG',),
#  ('ABIM',),
#  ('ABIM',),
#  ('NAPAK',),
#  ('ABIM',),
#  ('ABIM',),
#  ('KAABONG',),
#  ('KAABONG',),
#  ('MOROTO',),
#  ('AMUDAT',),
#  ('NAKAPIRIPIRIT',),
#  ('MOROTO',),
#  ('MOROTO',)]

# %%
#Select only the Sub counties from the Moroto district, order them alphabetically and show their production of sorghum.
# %%sql
SELECT SUBCOUNTY_NAME , S_Prod_Tot FROM Karamoja
WHERE DISTRICT_NAME = "MOROTO" 
ORDER BY SUBCOUNTY_NAME ASC;
# Out:
#  * sqlite://
# Done.
# [('KATIKEKILE', 9379.029413),
#  ('NADUNGET', 321630.539),
#  ('NORTHERN DIVISION', 17.28125956),
#  ('RUPA', 227298.5184),
#  ('SOUTHERN DIVISION', 19.67486547),
#  ('TAPAC', 49251.66081)]

# %%
#Compute the total Maize production per District.
# %%sql
SELECT COUNT(M_Prod_Tot), DISTRICT_NAME FROM Karamoja 
GROUP BY DISTRICT_NAME
# Out:
#  * sqlite://
# Done.
# [(6, 'ABIM'),
#  (4, 'AMUDAT'),
#  (14, 'KAABONG'),
#  (6, 'KOTIDO'),
#  (6, 'MOROTO'),
#  (8, 'NAKAPIRIPIRIT'),
#  (8, 'NAPAK')]

# %%
#Compute the number of Sub counties where Maize is produced and the total Maize production per District.
# %%sql
SELECT DISTRICT_NAME, M_Prod_Tot, COUNT(SUBCOUNTY_NAME) FROM Karamoja
GROUP BY DISTRICT_NAME
# Out:
#  * sqlite://
# Done.
# [('ABIM', 258010.2444, 6),
#  ('AMUDAT', 2081.356199, 4),
#  ('KAABONG', 136265.6835, 14),
#  ('KOTIDO', 179681.139, 6),
#  ('MOROTO', 155838.875, 6),
#  ('NAKAPIRIPIRIT', 1198586.875, 8),
#  ('NAPAK', 414509.6206, 8)]

# %%
#Compute the overall Crop area in all Sub counties where population is over 20000.
# %%sql
SELECT Crop_Area_Ha , SUBCOUNTY_NAME FROM Karamoja
WHERE POP > 20000
# Out:
#  * sqlite://
# Done.
# [(13587.990759999999, 'KOTIDO'),
#  (1656.5318550000002, 'KOTIDO TOWN COUNCIL'),
#  (7087.823334000001, 'NAKAPERIMORU'),
#  (10398.24939, 'PANYANGARA'),
#  (13278.52043, 'RENGEN'),
#  (1021.31699, 'KAABONG  EAST'),
#  (175.08052659999998, 'KAABONG TOWN COUNCIL'),
#  (967.3367266, 'KAABONG WEST'),
#  (2834.349905, 'KALAPATA'),
#  (997.1610206, 'KAMION'),
#  (2365.259806, 'KAPEDO'),
#  (6890.699234000001, 'KATHILE'),
#  (3934.432233, 'KAWALAKOL'),
#  (1890.248613, 'LOBALANGIT'),
#  (401.7978207, 'LODIKO'),
#  (2700.676313, 'LOLELIA'),
#  (1494.047587, 'NAPORE (KARENGA)'),
#  (957.4939457999999, 'SIDOK'),
#  (2513.27183, 'KARITA'),
#  (1539.401382, 'LOROO'),
#  (1651.99842, 'AMUDAT'),
#  (2480.1219, 'NADUNGET'),
#  (1111.664207, 'TAPAC'),
#  (5759.618906000001, 'LOREGAE'),
#  (5793.5076229999995, 'NAMALU'),
#  (5079.779088, 'LOLACHAT'),
#  (3276.653762, 'NABILATUK'),
#  (5473.443674, 'IRIIRI'),
#  (2990.847377, 'MATANY'),
#  (1215.227445, 'NGOLERIET'),
# ...

# %%
#Sort the Maize production in descending order by Districts, only taking into account Sub counties where Maize area is larger than Sorghum area, and display the number of Sub counties per district matching that criteria.
# %%sql
SELECT M_Prod_Tot FROM Karamoja
WHERE M_Yield_Ha > S_Yield_Ha
GROUP BY SUBCOUNTY_NAME
ORDER BY DISTRICT_NAME DESC;
# Out:
#  * sqlite://
# Done.
# [(3354666.348,),
#  (414509.6206,),
#  (1006139.305,),
#  (301833.0535,),
#  (39634.98127,),
#  (143401.6585,),
#  (291177.2726,),
#  (36017.149410000005,),
#  (602917.1224,),
#  (803244.7393,),
#  (963132.1158,),
#  (63990.504570000005,),
#  (1198586.875,),
#  (93265.78063,),
#  (34961.59076,),
#  (4365057.517,),
#  (56404.03821,),
#  (41687.926510000005,),
#  (46.22440465,),
#  (155838.875,),
#  (168139.0047,),
#  (600723.8929,),
#  (959201.3825,),
#  (9991.488268000001,),
#  (38971.65908,),
#  (221609.5114,),
#  (179681.139,),
#  (10181.201,),
#  (22772.636430000002,),
#  (59450.18942,),
#  (209806.09699999998,),
#  (392864.0158,),
#  (744375.6816,),
#  (976952.2116,),
#  (1412776.9819999998,),
#  (990983.0661,),
#  (61343.42645,),
#  (836095.3853,),
#  (201613.3805,),
#  (934881.6576,),
#  (136265.6835,),
#  (1340672.952,),
#  (2081.356199,),
#  (1415591.549,),
#  (788123.4753,),
#  (306951.8167,),
#  (299895.1917,),
#  (446294.5944,),
#  (322910.6857,),
# ...
